# %% [markdown]
# <a href="https://colab.research.google.com/github/AttiyaRaess/attiya/blob/main/Regession.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello python")
# Out:
# hello python

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
df=pd.read_csv('f.csv')
print(df)
# Out:
#    Unnamed: 0  area   price
# 0           0  2600  550000
# 1           1  2800  565000
# 2           2  3200  610000
# 3           3  3600  620000
# 4           4  4000  725000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='purple',marker='+')
